# %% [markdown]
# **how to create null value in data**

# %%
import numpy as np
import pandas as pd

# %%
d={'names':['ramesh','suresh',None,'sathish'],
  'age':[None,22,24,25],
  'city':['hyd','blr','pune',None]}
df1=pd.DataFrame(d)
df1df1
# Out:
#      names   age  city
# 0   ramesh   NaN   hyd
# 1   suresh  22.0   blr
# 2     None  24.0  pune
# 3  sathish  25.0  None

# %%
df1.to_csv('data1.csv',index=False)

# %%
d={'names':['ramesh','suresh',np.nan,'sathish'],
  'age':[np.nan,22,24,25],
  'city':['hyd','blr','pune',np.nan]}
df2=pd.DataFrame(d)
df2
# Out:
#      names   age  city
# 0   ramesh   NaN   hyd
# 1   suresh  22.0   blr
# 2      NaN  24.0  pune
# 3  sathish  25.0   NaN

# %%
df2.to_csv('data2.csv',index=False)

# %% [markdown]
#  - categorical data use None
#  - numerical data use np.nan

# %%
df1.isnull()
#is null()=wherever null value is there it will display as True
# Out:
#    names    age   city
# 0  False   True  False
# 1  False  False  False
# 2   True  False  False
# 3  False  False   True

# %%
df1.isnull().sum()
# Out:
# names    1
# age      1
# city     1
# dtype: int64

# %%
df1.values
# Out:
# array([['ramesh', nan, 'hyd'],
#        ['suresh', 22.0, 'blr'],
#        [None, 24.0, 'pune'],
#        ['sathish', 25.0, None]], dtype=object)

# %%
df1.dtypes
# Out:
# names     object
# age      float64
# city      object
# dtype: object

# %% [markdown]
# **filling values**

# %%
# Random filling
df1.fillna(30)
# Out:
#      names   age  city
# 0   ramesh  30.0   hyd
# 1   suresh  22.0   blr
# 2       30  24.0  pune
# 3  sathish  25.0    30

# %%
#select 1 column and fill it with the value
df1['age'].fillna(30)
# Out:
# 0    30.0
# 1    22.0
# 2    24.0
# 3    25.0
# Name: age, dtype: float64

# %%
df1.fillna(method='pad')
# Out:
# C:\Users\Teja\AppData\Local\Temp\ipykernel_29084\3887010614.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method='pad')
#      names   age  city
# 0   ramesh   NaN   hyd
# 1   suresh  22.0   blr
# 2   suresh  24.0  pune
# 3  sathish  25.0  pune

# %%
df1.fillna(method='pad',axis=1)
# Out:
# C:\Users\Teja\AppData\Local\Temp\ipykernel_29084\1258234312.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method='pad',axis=1)
#      names     age  city
# 0   ramesh  ramesh   hyd
# 1   suresh    22.0   blr
# 2     None    24.0  pune
# 3  sathish    25.0  25.0

# %%
df1.fillna(method='bfill')
# Out:
# C:\Users\Teja\AppData\Local\Temp\ipykernel_29084\2949398996.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method='bfill')
#      names   age  city
# 0   ramesh  22.0   hyd
# 1   suresh  22.0   blr
# 2  sathish  24.0  pune
# 3  sathish  25.0  None

# %%
df1.fillna(method='bfill',axis=1)
# Out:
# C:\Users\Teja\AppData\Local\Temp\ipykernel_29084\2900121331.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method='bfill',axis=1)
#      names   age  city
# 0   ramesh   hyd   hyd
# 1   suresh  22.0   blr
# 2     24.0  24.0  pune
# 3  sathish  25.0  None

# %%
df1.fillna(method='ffill')
# Out:
# C:\Users\Teja\AppData\Local\Temp\ipykernel_29084\598575452.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method='ffill')
#      names   age  city
# 0   ramesh   NaN   hyd
# 1   suresh  22.0   blr
# 2   suresh  24.0  pune
# 3  sathish  25.0  pune

# %%
df1.fillna(method='backfill')
# Out:
# C:\Users\Teja\AppData\Local\Temp\ipykernel_29084\2955370104.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method='backfill')
#      names   age  city
# 0   ramesh  22.0   hyd
# 1   suresh  22.0   blr
# 2  sathish  24.0  pune
# 3  sathish  25.0  None

# %%
df1['age'].fillna(df1['age'].mean())
# Out:
# 0    23.666667
# 1    22.000000
# 2    24.000000
# 3    25.000000
# Name: age, dtype: float64

# %%
df1['age'].fillna(df1['age'].median())
# Out:
# 0    24.0
# 1    22.0
# 2    24.0
# 3    25.0
# Name: age, dtype: float64

# %% [markdown]
# - KNN : K-nearest neighbours
# - where k is a number
# - insted of taking avg of all the values data
#     - first will find the neighbours who are close with missing data
#     - by using euclidian distance calculation will identify the neighbours rows
#     - suppose k=2 will identify two closeset rows
#     - those closest row values will take it will calculate the mean
#     - finally will fill with the mean

# %%
from sklearn.impute import KNNImputer
imputer=KNNImputer(n_neighbors=2)
imputer.fit_transform(df1['names'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 3
#       1 from sklearn.impute import KNNImputer
#       2 imputer=KNNImputer(n_neighbors=2)
# ----> 3 imputer.fit_transform(df1['names'])
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...
